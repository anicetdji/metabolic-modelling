# %%
import cobra
import pandas as pd
import cameo

# %%
wd = '/Users/aalarcon/Documents/Jupyter/3_Isopropanol/'

# %%
name_model = 'PKT'
souche = name_model.split('_')[0]
model = cobra.io.read_sbml_model(wd+'files/models/model_'+souche+'_Isopropanol_iML1515.xml')

cobra.io.save_json_model('/Users/alfredo/modsouch/data/static/metabolic-modelling/models/iML1515_PKT_IPA.json')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-322bd4f42b68> in <module>()
#       1 name_model = 'PKT'
#       2 souche = name_model.split('_')[0]
# ----> 3 model = cobra.io.read_sbml_model(wd+'files/models/model_'+souche+'_Isopropanol_iML1515.xml')
#       4
#       5 cobra.io.save_json_model('/Users/alfredo/modsouch/data/static/metabolic-modelling/models/iML1515_PKT_IPA.json')
#
# /anaconda3/envs/modelling/lib/python3.4/site-packages/cobra/io/sbml3.py in read_sbml_model(filename, number, **kwargs)
#     566     if not _with_lxml:
#     567         warn("Install lxml for faster SBML I/O", ImportWarning)
# --> 568     xmlfile = parse_stream(filename)
#     569     xml = xmlfile.getroot()
#     570     # use libsbml if not l3v1 with fbc v2
#
# /anaconda3/envs/modelling/lib/python3.4/site-packages/cobra/io/sbml3.py in parse_stream(filename)
#     150                 return parse(infile)
#     151         else:
# --> 152             return parse(filename)
#     153     except ParseError as e:
#     154         raise CobraSBMLError("Malformed XML file: " + str(e))
#
# src/lxml/lxml.etree.pyx in lxml.etree.parse (src/lxml/lxml.etree.c:81117)()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument (src/lxml/lxml.etree.c:117848)()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL (src/lxml/lxml.etree.c:118195)()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile (src/lxml/lxml.etree.c:117107)()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile (src/lxml/lxml.etree.c:111653)()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc (src/lxml/lxml.etree.c:105109)()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult (src/lxml/lxml.etree.c:106817)()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError (src/lxml/lxml.etree.c:105628)()
#
# OSError: Error reading file '/Users/aalarcon/Documents/Jupyter/3_Isopropanol/files/models/model_PKT_Isopropanol_iML1515.xml': failed to load external entity "/Users/aalarcon/Documents/Jupyter/3_Isopropanol/files/models/model_PKT_Isopropanol_iML1515.xml"

# %%
# try pfba
res = cameo.pfba(model)
# Save Model
cobra.io.save_json_model(model, wd+'input/models/model_'+name_model+'.json')
