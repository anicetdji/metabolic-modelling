# %%
import cameo

# %%
model = cameo.load_model('iML1515')

# %%
for g in model.genes:
    print(g.id,g.name)
# Out:
# b2551 glyA
# b0870 ltaE
# b3368 cysG
# b2436 hemF
# b3500 gor
# b0945 pyrD
# b4467 glcF
# b4468 glcE
# b2979 glcD
# b3916 pfkA
# b1260 trpA
# b1261 trpB
# b3426 glpD
# b2242 glpB
# b2243 glpC
# b2241 glpA
# b4054 tyrB
# b3770 ilvE
# b3281 aroE
# b1692 ydiB
# b0243 proA
# b1613 manA
# b0414 ribD
# b3041 ribB
# b0025 ribF
# b0844 ybjI
# b0446 cof
# b3812 yigB
# b1662 ribC
# b0421 ispA
# b3804 hemD
# b3997 hemE
# b4382 deoA
# b0126 can
# b0339 cynT
# b4006 purH
# b2508 guaB
# b3846 fadB
# b2341 fadJ
# b2400 gltX
# b3993 thiE
# b2066 udk
# b0238 gpt
# b0125 hpt
# b0474 adk
# b2518 ndk
# b1062 pyrC
# b1281 pyrF
# b0720 gltA
# b1136 icd
# b1241 adhE
# b0351 mhpF
# b4069 acs
# b2502 ppx
# b4226 ppa
# b2744 umpG
# b3403 pck
# b1479 maeA
# b1190 dadX
# b4053 alr
# b2379 alaC
# b2290 alaA
# b3564 xylB
# b0063 araB
# b3752 rbsK
# b3926 glpK
# b4383 deoB
# b0928 aspC
# b2930 yggF
# b4232 fbp
# b3697 yidA
# b3925 glpX
# b3430 glgC
# b1854 pykA
# b1676 pykF
# b2708 srlQ
# b3197 kdsD
# b0071 leuD
# ...
