# %%
import pandas as pd
import cobra
import cameo
from analysis_model import *
from bilansC import *
import escher
from cameo.flux_analysis.simulation import room, lmoma
from numpy import fabs
import seaborn as sns

# %%
show_escher = False
pd.options.display.max_colwidth = 1000
pd.options.display.max_rows = 1000
pd.options.display.column_space = 1000

# %%
wd = '/Users/aalarcon/Documents/Jupyter/3_Isopropanol/'
scen = ['WT', 'WT_PFL', 'WT_PTA', 'WT_PPC', 'WT_ADH', 'WT_PYK']
react_ko = {'WT':None, 'WT_PFL':'PFL', 'WT_PTA':'PTAr', 'WT_PPC':'PPC', 'WT_ADH':'LDH_D', 'WT_PYK':'PYK'}

# %%
model_WT =  cameo.load_model(wd+'files/models/model_WT_Acetone_iML1515.xml')
model_WT.solver = 'glpk'

# %%
reaction_data = {}
model = {}


for s in scen:
    model[s] = model_WT.copy()
    model[s].reactions.EX_o2_e.bounds = (-10,0)
    if s != 'WT':
        react_ko = s.split('_')[-1]
        model[s].reactions.get_by_id(react_ko).bounds = (0,0)
    reaction_data = cameo.pfba(model[s]).fluxes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-5db3362feba7> in <module>()
#       6     if s != 'WT':
#       7         react_ko = s.split('_')[-1]
# ----> 8         model[s].reactions.get_by_id(react_ko).bounds = (0,0)
#       9     reaction_data = cameo.pfba(model[s]).fluxes
#
# /Users/aalarcon/anaconda/envs/cameo3.4/lib/python3.4/site-packages/cobra/core/dictlist.py in get_by_id(self, id)
#      52     def get_by_id(self, id):
#      53         """return the element with a matching id"""
# ---> 54         return list.__getitem__(self, self._dict[id])
#      55
#      56     def list_attr(self, attribute):
#
# KeyError: 'D'
