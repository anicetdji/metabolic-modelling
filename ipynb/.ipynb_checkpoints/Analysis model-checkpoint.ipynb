# %%
import pandas as pd
import cobra
import cameo

# %%
wd = '/Users/alfredo/Documents/Jupyter/3_Isopropanol/ipynb/'

# %%
model = cameo.load_model('iML1515')

# %%
reacts_exchange = []
for r in model.reactions:
    reactants_p = [m for m in r.metabolites if r.metabolites[m]<0 and m.id.endswith('_p')]
    products_p = [m for m in r.metabolites if r.metabolites[m]>0 and m.id.endswith('_p')]
    reactants_c = [m for m in r.metabolites if r.metabolites[m]<0 and m.id.endswith('_c')]
    products_c = [m for m in r.metabolites if r.metabolites[m]>0 and m.id.endswith('_c')]
    
    if (len(reactants_p)>0 and len(reactants_c)>0) or (len(reactants_c)>0 and len(reactants_p)>0):
        reacts_exchange.append(r)

# %%
len(reacts_exchange)
# Out:
# 205

# %%
def get_metabolite_transported(r):
    reactants = [m.id for m in r.metabolites if r.metabolites[m]<0]
    products = [m.id for m in r.metabolites if r.metabolites[m]>0]
    for react in reactants:
        if react.id.endswith('_c') and react.id.replace('_c','_p') in [p.id for p in products]:
            return react
        elif react.id.endswith('_p') and react.id.replace('_p','_c') in [p.id for p in products]:
            return model.metabolites.get_by_id(react.id.replace('_p','_c'))

# %%
rex_ok =

# %%
df_rex = pd.DataFrame(index=[r.id for r in reacts_exchange])
df_rex['reaction'] = [r.build_reaction_string() for r in reacts_exchange]
df_rex['genes'] = [' '.join(list([g.id for g in r.genes])) for r in reacts_exchange]
df_rex['description'] = [r.name for r in reacts_exchange]

# %%
df_rex
# Out:
#                                                                          reaction  \
# NMNt7pp                                    h2o_c + nmn_p --> h_c + ncam_c + r5p_c
# FACOAL160t2pp                   atp_c + coa_c + h_p + hdca_p --> amp_c + h_c +...
# FACOAL180t2pp                   atp_c + coa_c + h_p + ocdca_p --> amp_c + h_c ...
# NO3R1bpp                                  no3_p + q8h2_c --> h2o_p + no2_p + q8_c
# NO3R2bpp                                mql8_c + no3_p --> h2o_p + mqn8_c + no2_p
# THD2pp                          2.0 h_p + nadh_c + nadp_c --> 2.0 h_c + nad_c ...
# TMAOR1pp                         h_p + mql8_c + tmao_p --> h2o_p + mqn8_c + tma_p
# TMAOR2pp                        2dmmql8_c + h_p + tmao_p --> 2dmmq8_c + h2o_p ...
# SUCFUMtpp                                       fum_p + succ_c <=> fum_c + succ_p
# SUCptspp                                       pep_c + sucr_p --> pyr_c + suc6p_c
# SULabcpp                        atp_c + h2o_c + so4_p --> adp_c + h_c + pi_c +...
# TSULabcpp                       atp_c + h2o_c + tsul_p --> adp_c + h_c + pi_c ...
# TARTRt7pp                             succ_c + tartr__L_p <=> succ_p + tartr__L_c
# TAURabcpp                       atp_c + h2o_c + taur_p --> adp_c + h_c + pi_c ...
# THMabcpp                        atp_c + h2o_c + thm_p --> adp_c + h_c + pi_c +...
# THRabcpp                        atp_c + h2o_c + thr__L_p --> adp_c + h_c + pi_...
# TREptspp                                        pep_c + tre_p --> pyr_c + tre6p_c
# VALabcpp                        atp_c + h2o_c + val__L_p --> adp_c + h_c + pi_...
# XYLabcpp                        atp_c + h2o_c + xyl__D_p --> adp_c + h_c + pi_...
# FEOXAMabcpp                     atp_c + feoxam_p + h2o_c --> adp_c + feoxam_c ...
# CBL1abcpp                       atp_c + cbl1_p + h2o_c --> adp_c + cbl1_c + h_...
# ACGAptspp                                   acgam_p + pep_c --> acgam6p_c + pyr_c
# ACMANAptspp                                acmana_p + pep_c --> acmanap_c + pyr_c
# FEENTERabcpp                    atp_c + feenter_p + h2o_c --> adp_c + feenter_...
# FECRMabcpp                      atp_c + fecrm_p + h2o_c --> adp_c + fecrm_c + ...
# DAPabcpp                        26dap__M_p + atp_c + h2o_c --> 26dap__M_c + ad...
# DMSOR1pp                               dmso_p + mql8_c --> dms_p + h2o_p + mqn8_c
# ARGabcpp                        arg__L_p + atp_c + h2o_c --> adp_c + arg__L_c ...
# ARGAGMt7pp                                  agm_c + arg__L_p <=> agm_p + arg__L_c
# ASCBptspp                                  ascb__L_p + pep_c --> ascb6p_c + pyr_c
# ...                                                                           ...
# ACOLIPAabctex                   acolipa_p + atp_c + h2o_c --> acolipa_e + adp_...
# ECA4COLIPAabctex                atp_c + eca4colipa_p + h2o_c --> adp_c + eca4c...
# COLIPAPabctex                   atp_c + colipap_p + h2o_c --> adp_c + colipap_...
# ARBTptspp                                     arbt_p + pep_c --> arbt6p_c + pyr_c
# SUCASPtpp                                 asp__L_p + succ_c <=> asp__L_c + succ_p
# SUCMALtpp                                 mal__L_p + succ_c <=> mal__L_c + succ_p
# SUCTARTtpp                            succ_c + tartr__D_p <=> succ_p + tartr__D_c
# CHTBSptspp                                  chtbs_p + pep_c --> chtbs6p_c + pyr_c
# SPMDt3pp                                            h_p + spmd_c --> h_c + spmd_p
# MALt3pp                                         h_p + mal__L_c --> h_c + mal__L_p
# CITt3pp                                               cit_c + h_p --> cit_p + h_c
# GLYC2Pabcpp                     atp_c + glyc2p_p + h2o_c --> adp_c + glyc2p_c ...
# SELabcpp                        atp_c + h2o_c + sel_p --> adp_c + h_c + pi_c +...
# DHBSZ3FEabcpp                   atp_c + fe3dhbzs3_p + h2o_c --> adp_c + fe3dhb...
# 2DGLCptspp                                  2dglc_p + pep_c --> 2doxg6p_c + pyr_c
# CHLt3pp                                             chol_c + h_p --> chol_p + h_c
# GLYBt3pp                                            glyb_c + h_p --> glyb_p + h_c
# CHOLATEtpp                                    cholate_c + h_p --> cholate_p + h_c
# ILEt3pp                                         h_p + ile__L_c --> h_c + ile__L_p
# METt3pp                                         h_p + met__L_c --> h_c + met__L_p
# GSNt3pp                                               gsn_c + h_p --> gsn_p + h_c
# LEUt3pp                                         h_p + leu__L_c --> h_c + leu__L_p
# INSt3pp                                               h_p + ins_c --> h_c + ins_p
# AI2abcpp                        atp_c + h2o_c + mththf_p --> adp_c + h_c + mth...
# 4HBZt3pp                                            4hbz_c + h_p --> 4hbz_p + h_c
# MEPNabcpp                       atp_c + h2o_c + mepn_p --> adp_c + h_c + mepn_...
# SLNTabcpp                       atp_c + h2o_c + slnt_p --> adp_c + h_c + pi_c ...
# VALt3pp                                         h_p + val__L_c --> h_c + val__L_p
# BIOMASS_Ec_iML1515_core_75p37M  0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223...
# BIOMASS_Ec_iML1515_WT_75p37M    0.000223 10fthf_c + 0.000223 2dmmql8_c + 2.5e-...
#
#                                                                             genes  \
# NMNt7pp
# FACOAL160t2pp                                                         b1701 b1805
# FACOAL180t2pp                                                         b1701 b1805
# NO3R1bpp                                            b2205 b2203 b2202 b2204 b2206
# NO3R2bpp                                                        b2203 b2202 b2206
# THD2pp                                                                b1602 b1603
# TMAOR1pp                                                  b1872 b0997 b0996 b1873
# TMAOR2pp                                                  b1872 b0997 b0996 b1873
# SUCFUMtpp                                                       b4138 b0621 b4123
# SUCptspp                                                  b2417 b2429 b2415 b2416
# SULabcpp                          b2423 b0765 b2424 b2422 b2425 b0763 b3917 b0764
# TSULabcpp                                           b2423 b2422 b2425 b3917 b2424
# TARTRt7pp                                                                   b3063
# TAURabcpp                                                       b0366 b0367 b0365
# THMabcpp                                                        b0067 b0066 b0068
# THRabcpp                                            b3454 b3456 b3457 b3455 b3460
# TREptspp                                                  b2417 b2416 b2415 b4240
# VALabcpp                                            b3454 b3456 b3457 b3455 b3460
# XYLabcpp                                                        b3566 b3567 b3568
# FEOXAMabcpp                                                     b0153 b0152 b0151
# CBL1abcpp                                                       b0158 b1711 b1709
# ACGAptspp                                           b2417 b1101 b2416 b2415 b0679
# ACMANAptspp                                         b2416 b2415 b1817 b1819 b1818
# FEENTERabcpp                                              b0588 b0592 b0590 b0589
# FECRMabcpp                                                      b0153 b0152 b0151
# DAPabcpp
# DMSOR1pp                                                              b1872 b1873
# ARGabcpp                        b0863 b0864 b0860 b2306 b0861 b2308 b2307 b231...
# ARGAGMt7pp                                                                  b4115
# ASCBptspp                                           b4194 b2416 b4195 b2415 b4193
# ...                                                                           ...
# ACOLIPAabctex                           b4262 b0641 b3199 b3201 b0054 b3200 b4261
# ECA4COLIPAabctex                        b4262 b0641 b3199 b3201 b0054 b3200 b4261
# COLIPAPabctex                           b4262 b0641 b3199 b3201 b0054 b3200 b4261
# ARBTptspp                                                 b2416 b2415 b2715 b3722
# SUCASPtpp                                                       b4138 b0621 b4123
# SUCMALtpp                                                       b4138 b0621 b4123
# SUCTARTtpp                                                                  b4123
# CHTBSptspp                                          b1736 b1738 b2416 b2415 b1737
# SPMDt3pp                                                              b1600 b1599
# MALt3pp
# CITt3pp
# GLYC2Pabcpp                                               b3451 b3453 b3452 b3450
# SELabcpp                                            b2423 b2422 b2425 b3917 b2424
# DHBSZ3FEabcpp                                             b0588 b0592 b0590 b0589
# 2DGLCptspp                                          b2416 b2415 b1817 b1819 b1818
# CHLt3pp                                                                     b0543
# GLYBt3pp                                                                    b0543
# CHOLATEtpp                                                                  b4337
# ILEt3pp                                                                     b4141
# METt3pp                                                               b4141 b1798
# GSNt3pp                                                                     b3662
# LEUt3pp                                                               b4141 b1798
# INSt3pp                                                                     b3662
# AI2abcpp                                                  b1514 b1516 b1515 b1513
# 4HBZt3pp                                                              b3240 b3241
# MEPNabcpp                                                       b4104 b4105 b4106
# SLNTabcpp                                           b2423 b2422 b2425 b3917 b2424
# VALt3pp                                                         b4141 b2683 b2682
# BIOMASS_Ec_iML1515_core_75p37M
# BIOMASS_Ec_iML1515_WT_75p37M
#
#                                                                       description
# NMNt7pp                          NMN transport via NMN glycohydrolase (periplasm)
# FACOAL160t2pp                   Fatty-acid-CoA ligase (hexadecanoate transport...
# FACOAL180t2pp                   Fatty-acid-CoA ligase (octadecanoate transport...
# NO3R1bpp                                          Nitrate reductase (Ubiquinol-8)
# NO3R2bpp                             Nitrate reductase (Menaquinol-8) (periplasm)
# THD2pp                                        NAD(P) transhydrogenase (periplasm)
# TMAOR1pp                        Trimethylamine N-oxide reductase (menaquinol 8...
# TMAOR2pp                        Trimethylamine N-oxide reductase (demethylmena...
# SUCFUMtpp                               Succinate:fumarate antiporter (periplasm)
# SUCptspp                               Sucrose transport via PEP:Pyr  (periplasm)
# SULabcpp                             Sulfate transport via ABC system (periplasm)
# TSULabcpp                        Thiosulfate transport via ABC system (periplasm)
# TARTRt7pp                               Tartrate/succinate antiporter (periplasm)
# TAURabcpp                            Taurine transport via ABC system (periplasm)
# THMabcpp                            Thiamine transport via ABC system (periplasm)
# THRabcpp                         L-threonine transport via ABC system (periplasm)
# TREptspp                          Trehalose transport via PEP:Pyr PTS (periplasm)
# VALabcpp                            L-valine transport via ABC system (periplasm)
# XYLabcpp                            D-xylose transport via ABC system (periplasm)
# FEOXAMabcpp                      Ferroxamine transport via ABC system (periplasm)
# CBL1abcpp                       Cob(1)alamin transport via ABC system (periplasm)
# ACGAptspp                       N-Acetyl-D-glucosamine transport via PEP:Pyr P...
# ACMANAptspp                     N-acetyl-D-mannosamine transport via PTS  (per...
# FEENTERabcpp                    Fe-enterobactin transport via ABC system (peri...
# FECRMabcpp                       Ferrichrome transport via ABC system (periplasm)
# DAPabcpp                          M-diaminopimelic acid ABC transport (periplasm)
# DMSOR1pp                        Dimethyl sulfoxide reductase (Menaquinol 8) (p...
# ARGabcpp                          L-arginine transport via ABC system (periplasm)
# ARGAGMt7pp                                 Arginine/agmatine antiport (periplasm)
# ASCBptspp                       L-ascorbate transport via PEP:Pyr PTS (periplasm)
# ...                                                                           ...
# ACOLIPAabctex                   Arabinose modified core oligosaccharide lipid ...
# ECA4COLIPAabctex                Enterobacterial common antigen (x4) core oligo...
# COLIPAPabctex                   Core oligosaccharide lipid A diphosphate trans...
# ARBTptspp                           Arbutin transport via PEP:Pyr PTS (periplasm)
# SUCASPtpp                              Succinate:aspartate antiporter (periplasm)
# SUCMALtpp                                 Succinate:malate antiporter (periplasm)
# SUCTARTtpp                            Succinate:D-tartrate antiporter (periplasm)
# CHTBSptspp                       Chitobiose transport via PEP:Pyr PTS (periplasm)
# SPMDt3pp                        Spermidine transport out via proton antiport (...
# MALt3pp                         L-malate transport out via proton antiport (pe...
# CITt3pp                         Citrate transport out via proton antiport (per...
# GLYC2Pabcpp                     Sn-Glycerol 2-phosphate transport via ABC syst...
# SELabcpp                        Selenatenate transport via ABC system (periplasm)
# DHBSZ3FEabcpp                   23dhbsz3 Fe III transport via ABC system perip...
# 2DGLCptspp                      2-Deoxy-D-glucose transport via PEP:Pyr PTS (p...
# CHLt3pp                         Choline transport via proton antiport (periplasm)
# GLYBt3pp                        Glycine betaine transport via proton antiport ...
# CHOLATEtpp                                  Cholate transport via proton antiport
# ILEt3pp                         L-isoleucine transport out via proton antiport...
# METt3pp                         L-methionine tranport out via proton antiport ...
# GSNt3pp                         Guanosine transport out via proton antiport (p...
# LEUt3pp                         L-leucine transport out via proton antiport (p...
# INSt3pp                         Inosine transport out via proton antiport (per...
# AI2abcpp                                            Autoinducer-2 ABC transporter
# 4HBZt3pp                           4-hydroxybenzoate transport out via antiporter
# MEPNabcpp                                   Methylpshophonic acid abc transporter
# SLNTabcpp                                    Selenite ABC transporter (periplasm)
# VALt3pp                         L-valine transport out via proton antiport (pe...
# BIOMASS_Ec_iML1515_core_75p37M  E. coli biomass objective function (iML1515) -...
# BIOMASS_Ec_iML1515_WT_75p37M    E. coli biomass objective function (iML1515) -...
#
# [205 rows x 3 columns]
