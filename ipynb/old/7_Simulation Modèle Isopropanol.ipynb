# %%
import cameo
import cobra
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from analysis_model import *
from bilansC import *

# %%
wd = '/Users/aalarcon/Documents/Jupyter/3_Isopropanol/'

# %%
model = cobra.io.read_sbml_model(wd+'input/models/model_PKT_isopropanol_iML1515.xml')

# %%
r_bm_id = 'BIOMASS_Ec_iML1515_WT_75p37M'

# %%
res = cameo.phenotypic_phase_plane(model, variables=r_bm_id, objective='AKGDH')

# %%
res = cameo.phenotypic_phase_plane(model, variables=r_bm_id, objective='EX_')
res.data_frame
plt.plot(res.data_frame.BIOMASS_Ec_iML1515_WT_75p37M, res.data_frame.objective_lower_bound)
plt.plot(res.data_frame.BIOMASS_Ec_iML1515_WT_75p37M, res.data_frame.objective_upper_bound)
plt.title('Production Envelope')
plt.ylabel('Metabolite Production')
plt.xlabel('Growth Rate')
